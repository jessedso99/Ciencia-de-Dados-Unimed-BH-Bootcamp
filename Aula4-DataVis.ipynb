# %% [markdown]
# <a href="https://colab.research.google.com/github/jessedso99/Ciencia-de-Dados-Bootcamp-Unimed-BH-DIO/blob/main/Aula4-DataVis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Datasets/dfVendas1.xlsx")
df.sample(5)
# Out:
#      Unnamed: 0          Cidade       Data  Vendas  LojaID  Qtde  Receita  \
# 126           6  Santa Catarina 2022-02-18  431.83    1015     6  2590.98
# 81           37  Rio de Janeiro 2020-09-12  160.14    1008     5   800.70
# 66           22  Rio de Janeiro 2020-10-22  629.73    1009     5  3148.65
# 33           33          Paraná 2021-09-11  247.11    1001     4   988.44
# 14           14          Paraná 2022-01-04   67.16    1002    30  2014.80
#
#      Ano_venda  Mes_venda  Dia_venda  Dif de dias  Trimestre_Venda
# 126       2022          2         18          605                1
# 81        2020          9         12           81                3
# 66        2020         10         22          121                4
# 33        2021          9         11          445                3
# 14        2022          1          4          560                1

# %%
#grafico de linhas (basta n informar qual tipo de plot vc quer. Apenas plot())
df.groupby('LojaID').agg(Qnt_Prod_Vendido=('Qtde', 'sum')).sort_values(by= ["Qnt_Prod_Vendido"], ascending= False).plot.bar()
df[["LojaID", "Qtde"]].loc[(df["LojaID"] == 1013)]
# Out:
#     LojaID  Qtde
# 83    1013     2
# 89    1013     0
# 96    1013     4

# %%
#Grafico de Barras Vertical
df["LojaID"].value_counts(ascending= False).plot.bar()

# %%
#Grafico de Barras Horizontal
df["LojaID"].value_counts(ascending= False).plot.barh()

# %%
#Grafico de Pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()

# %%
#Para personalizar o garfico, mudando cores, titulos, etc, é necessario importar a biblioteca matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
df["Cidade"].value_counts().plot.bar(title= "Total de vendas por Cidade", color= "red")
plt.xlabel("Estado")
plt.ylabel("Total Vendas")
plt.legend("Estados")

# %%
#Podemos ainda alterar o estilo do grafico. Os apresentados anteriomente são os Default.
#ver documentaçaõ do matplotlib
plt.style.use("ggplot")
df["Cidade"].value_counts().plot.barh(title= "Total de vendas por Cidade", color= "red")
plt.xlabel("Estado")
plt.ylabel("Total Vendas")
plt.legend();

# %%
#quantidad de produtos vedidos por mês durante o ano de 2020
vendas2020= df[df["Ano_venda"]==2020]
vendas2020.groupby(vendas2020["Mes_venda"])["Qtde"].sum().plot(marker= "v")
plt.xlabel("Mês")
plt.xlabel("Total Produtos vendidos")
plt.legend()
vendas2020.groupby(vendas2020["Mes_venda"])["Qtde"].sum()
# Out:
# Mes_venda
# 6      12
# 7      49
# 8      50
# 9      91
# 10    135
# 11     23
# 12     99
# Name: Qtde, dtype: int64

# %%
#Plotando HISTOGRAMA
plt.hist(df["Qtde"], color= "tan");
(df[["LojaID", "Qtde"]].loc[(df["Qtde"] <= df["Qtde"].max()) & (df["Qtde"] >= 30)]).shape
# Out:
# (10, 2)

# %%
#SCATTER PLOT, grafico de dispersão
plt.scatter(x= vendas2020["Dia_venda"], y= vendas2020["Receita"])

# %%
#SALVANDO OS GRAFICOS usando plt.savefig("title.png")
vendas2020= df[df["Ano_venda"]==2020]
vendas2020.groupby(vendas2020["Mes_venda"])["Qtde"].sum().plot(marker= "v")
plt.xlabel("Mês")
plt.xlabel("Total Produtos vendidos")
plt.legend()
vendas2020.groupby(vendas2020["Mes_venda"])["Qtde"].sum()
plt.savefig("QtdProd_vedido-mes_2020.png")
